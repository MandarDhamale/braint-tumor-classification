# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# 2025-10-21 19:39:16.269283: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# --- 1. SETUP DATA PATHS AND PARAMETERS ---
train_dir = 'data/train'
validation_dir = 'data/validation'
test_dir = 'data/test'

IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 16

# %%
# --- 2. PREPROCESSING AND DATA AUGMENTATION ---
train_datagen = ImageDataGenerator(
    rescale=1./255,         
    shear_range=0.2,         
    zoom_range=0.2,          
    horizontal_flip=True    
)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb' 
)

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False, 
    color_mode='rgb'
)
# Out:
# Found 2297 images belonging to 4 classes.
# Found 573 images belonging to 4 classes.
# Found 394 images belonging to 4 classes.

# %%
# --- 3. BUILD THE MODEL ARCHITECTURE ---
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

x = base_model.output
x = Flatten()(x) 
x = Dense(256, activation='relu')(x) 
predictions = Dense(4, activation='softmax')(x) 


model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761089962.249905   11430 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4136 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# --- 4. TWO-STAGE TRAINING AND FINE-TUNING ---

# === STAGE 1: Train Only the Top Layers ===
print("--- Starting Stage 1: Training the top layers ---")
# Freeze all layers of the base VGG16 model 
for layer in base_model.layers:
    layer.trainable = False

# Compile the model with the initial learning rate 
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model 
history_stage1 = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)

# === STAGE 2: Fine-Tuning ===
print("\n--- Starting Stage 2: Fine-tuning the model ---")
# Unfreeze the top layers of the base model for fine-tuning
# The paper unfreezes from the 11th layer onwards 
for layer in base_model.layers[10:]:
    layer.trainable = True

# Re-compile the model with a much lower learning rate for fine-tuning 
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Continue training the model (fine-tuning)
history_stage2 = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# --- Starting Stage 1: Training the top layers ---
# /home/mandar-dhamale/miniconda3/envs/ml-gpu/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 2025-10-21 19:39:25.319231: I external/local_xla/xla/service/service.cc:163] XLA service 0x7567d8005230 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-21 19:39:25.319245: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-10-21 19:39:25.392970: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-21 19:39:25.761305: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91400
# I0000 00:00:1761089986.154500   14100 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 84s 436ms/step - accuracy: 0.6721 - loss: 1.0275 - val_accuracy: 0.7536 - val_loss: 0.5610
# Epoch 2/50
#   1/143 ━━━━━━━━━━━━━━━━━━━━ 34s 246ms/step - accuracy: 0.6875 - loss: 0.9608
# /home/mandar-dhamale/miniconda3/envs/ml-gpu/lib/python3.10/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.6875 - loss: 0.9608 - val_accuracy: 0.7804 - val_loss: 0.4972
# Epoch 3/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 45s 317ms/step - accuracy: 0.8203 - loss: 0.4622 - val_accuracy: 0.8732 - val_loss: 0.3465
# Epoch 4/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8125 - loss: 0.4122 - val_accuracy: 0.8536 - val_loss: 0.3918
# Epoch 5/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s
50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0736 - val_accuracy: 0.9446 - val_loss: 0.1964
# Epoch 37/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 183ms/step - accuracy: 0.9855 - loss: 0.0484 - val_accuracy: 0.9571 - val_loss: 0.1528
# Epoch 38/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0214 - val_accuracy: 0.9625 - val_loss: 0.1472
# Epoch 39/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.9820 - loss: 0.0610 - val_accuracy: 0.9464 - val_loss: 0.1963
# Epoch 40/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0362 - val_accuracy: 0.9446 - val_loss: 0.1868
# Epoch 41/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.9689 - loss: 0.1018 - val_accuracy: 0.9000 - val_loss: 0.3632
# Epoch 42/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8750 - loss: 0.4972 - val_accuracy: 0.9286 - val_loss: 0.2382
# Epoch 43/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 27s 185ms/step - accuracy: 0.9781 - loss: 0.0615 - val_accuracy: 0.9607 - val_loss: 0.1590
# Epoch 44/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.9554 - val_loss: 0.1652
# Epoch 45/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.9908 - loss: 0.0298 - val_accuracy: 0.9732 - val_loss: 0.1227
# Epoch 46/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9375 - loss: 0.1752 - val_accuracy: 0.9750 - val_loss: 0.1145
# Epoch 47/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 183ms/step - accuracy: 0.9698 - loss: 0.0910 - val_accuracy: 0.9339 - val_loss: 0.2616
# Epoch 48/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.9375 - val_loss: 0.2396
# Epoch 49/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.9833 - loss: 0.0498 - val_accuracy: 0.9625 - val_loss: 0.1199
# Epoch 50/50
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9375 - loss: 0.0610 - val_accuracy: 0.9589 - val_loss: 0.1375

# %%
# --- 5. EVALUATE THE FINAL MODEL ---
print("\n--- Evaluating the final model on the test set ---")
# Evaluate the model on the test data
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples // BATCH_SIZE)
print(f"Final Test Accuracy: {accuracy*100:.2f}%") # The paper achieved 99.24% 
print(f"Final Test Loss: {loss:.4f}")

Y_pred = model.predict(test_generator, test_generator.samples // BATCH_SIZE + 1)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_generator.classes

class_labels = list(test_generator.class_indices.keys())

# --- 6. DISPLAY PERFORMANCE METRICS ---

print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Generate and plot the confusion matrix 
print("\n--- Confusion Matrix ---")
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# --- Evaluating the final model on the test set ---
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.7891 - loss: 1.7552
# Final Test Accuracy: 78.91%
# Final Test Loss: 1.7552
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#       glioma       1.00      0.37      0.54       100
#   meningioma       0.76      0.95      0.84       115
#     no_tumor       0.70      0.99      0.82       105
#    pituitary       0.95      0.85      0.90        74
#
#     accuracy                           0.79       394
#    macro avg       0.85      0.79      0.78       394
# weighted avg       0.84      0.79      0.77       394
#
#
# --- Confusion Matrix ---
